# %%
import pandas as pd

# %%
archivo = "../data/resultado_520ppm.csv"
r520ppm = pd.read_csv(archivo,header=[0,1],index_col=0)


archivo = "../data/resultado_625ppm.csv"
r625ppm = pd.read_csv(archivo,header=[0,1],index_col=0)


archivo = "../data/resultado_750ppm.csv"
r750ppm = pd.read_csv(archivo,header=[0,1],index_col=0)

archivo = "../data/resultado_800ppm.csv"
r800ppm = pd.read_csv(archivo,header=[0,1],index_col=0)

archivo = "../data/resultado_893ppm.csv"
r893ppm = pd.read_csv(archivo,header=[0,1],index_col=0)

# %%
resultados  = pd.concat([r520ppm,r625ppm,r750ppm,r800ppm,r893ppm],axis=1)
resultados
# Out:
#                            scd30                 sen0220  \
#                           515ppm                  515ppm
# Variable
# TR+       0 days 00:00:08.195000  0 days 00:16:43.895000
# M              488.5405405405405       535.7380952380952
# D_r            515.6566666666666       515.6566666666666
# Error         -27.11612612612612      20.081428571428546
#
#                             s8lp                cjmcu811  \
#                           515ppm                  515ppm
# Variable
# TR+       0 days 00:26:57.822000  0 days 00:22:27.045000
# M              549.7377049180328                  3610.1
# D_r            515.6566666666666       515.6566666666666
# Error          34.08103825136618       3094.443333333333
#
#                            scd30                 sen0220  \
#                           633ppm                  633ppm
# Variable
# TR+       0 days 00:04:38.559000  0 days 00:08:12.755000
# M               586.081081081081        645.047619047619
# ...

# %%
resultados["scd30"]
# Out:
#                           515ppm                  633ppm  \
# Variable
# TR+       0 days 00:00:08.195000  0 days 00:04:38.559000
# M              488.5405405405405        586.081081081081
# D_r            515.6566666666666       633.0433333333333
# Error         -27.11612612612612     -46.962252252252256
#
#                           755ppm                  800ppm  \
# Variable
# TR+       0 days 00:14:24.528000  0 days 00:00:08.195000
# M               713.536231884058       762.4594594594595
# D_r            755.3883333333333                  800.18
# Error        -41.852101449275324      -37.72054054054047
#
#                           888ppm
# Variable
# TR+       0 days 00:09:27.765000
# M                          852.9
# D_r                       888.65
# Error                     -35.75

# %%
resultados.iloc[:,0:2]
# Out:
#                            scd30                 sen0220
#                           515ppm                  515ppm
# Variable
# TR+       0 days 00:00:08.195000  0 days 00:16:43.895000
# M              488.5405405405405       535.7380952380952
# D_r            515.6566666666666       515.6566666666666
# Error         -27.11612612612612      20.081428571428546
