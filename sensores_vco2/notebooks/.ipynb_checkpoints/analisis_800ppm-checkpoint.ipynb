# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse

# %%
from sensores import *

# %%
archivo = "../data/fluke_26-07-2021_800ppm.csv"
fluke = pd.read_csv(archivo,index_col=0,parse_dates=True)
fluke.head(3)
# Out:
#                      fluke
# tiempo
# 2021-07-26 14:00:00  434.0
# 2021-07-26 14:00:01  434.0
# 2021-07-26 14:00:02  439.0

# %%
tb = pd.read_csv("../data/sensores_26-07-2021_800ppm.csv",index_col=0,parse_dates=True)
del tb["t3022"]
sensores = tb.columns

# %%
inte = "2Min"
int2 = "10Min"
analiza_sensor(fluke,fluke,sensor="fluke",grafica=True,int_promedio=int2,intervalo=inte,imprime=True)
# Out:
# fluke                    800ppm
# Variable
# TR+       0 days 00:00:01
# M                  800.18
# D_r                800.18
# Error                 0.0
#                    800ppm
# Variable
# TR+       0 days 00:00:01
# M                  800.18
# D_r                800.18
# Error                 0.0

# %%
for sensor in sensores:
    analiza_sensor(tb,fluke,sensor=sensor,grafica=True,intervalo='2Min',imprime=True)
# Out:
# s8lp                           801ppm
# Variable
# TR+       0 days 00:06:49.432000
# M                     827.934426
# D_r                   801.246667
# Error                   26.68776
# sen0220                           801ppm
# Variable
# TR+       0 days 00:00:06.560000
# M                     804.404762
# D_r                   801.246667
# Error                   3.158095
# scd30                           801ppm
# Variable
# TR+       0 days 00:00:08.195000
# M                     763.162162
# D_r                   801.246667
# Error                 -38.084505
# cjmcu811                           801ppm
# Variable
# TR+       0 days 00:15:29.196000
# M                        3869.98
# D_r                   801.246667
# Error                3068.733333

# %%
inte = "2Min"
int2 = "10Min"
scd30    = analiza_sensor(tb,fluke,sensor="scd30",   grafica=False,int_promedio=int2,intervalo=inte)
sen0220  = analiza_sensor(tb,fluke,sensor="sen0220", grafica=False,int_promedio=int2,intervalo=inte)
s8lp     = analiza_sensor(tb,fluke,sensor="s8lp",    grafica=False,int_promedio=int2,intervalo=inte)
cjmcu811 = analiza_sensor(tb,fluke,sensor="cjmcu811",grafica=False,int_promedio=int2,intervalo=inte)
resultados_520ppm = pd.concat([scd30,sen0220,s8lp,cjmcu811],
                             axis=1,
                              keys=['scd30','sen0220','s8lp','cjmcu811'])
resultados_520ppm
# Out:
#                            scd30                 sen0220  \
#                           800ppm                  800ppm
# Variable
# TR+       0 days 00:00:08.195000  0 days 00:00:06.560000
# M                     762.459459              803.666667
# D_r                       800.18                  800.18
# Error                 -37.720541                3.486667
#
#                             s8lp                cjmcu811
#                           800ppm                  800ppm
# Variable
# TR+       0 days 00:06:49.432000  0 days 00:15:29.196000
# M                     827.884298                 3906.06
# D_r                       800.18                  800.18
# Error                  27.704298                 3105.88
