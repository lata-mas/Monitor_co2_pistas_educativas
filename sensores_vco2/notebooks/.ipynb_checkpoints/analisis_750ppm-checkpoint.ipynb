# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse

# %%
from sensores import *

# %%
archivo = "../data/fluke_26-07-2021_750ppm.csv"
fluke = pd.read_csv(archivo,index_col=0,parse_dates=True)
fluke.head(3)
# Out:
#                      fluke
# tiempo
# 2021-07-26 15:42:00  437.0
# 2021-07-26 15:42:01  437.0
# 2021-07-26 15:42:02  440.0

# %%
tb = pd.read_csv("../data/sensores_26-07-2021_750ppm.csv",index_col=0,parse_dates=True)
del tb["t3022"]
sensores = tb.columns

# %%
inte = "2Min"
int2 = "10Min"
analiza_sensor(fluke,fluke,sensor="fluke",grafica=True,int_promedio=int2,intervalo=inte,imprime=True)
# Out:
# fluke                    755ppm
# Variable
# TR+       0 days 00:00:01
# M              755.388333
# D_r            755.388333
# Error                 0.0
#                    755ppm
# Variable
# TR+       0 days 00:00:01
# M              755.388333
# D_r            755.388333
# Error                 0.0

# %%
for sensor in sensores:
    analiza_sensor(tb,fluke,sensor=sensor,grafica=True,intervalo='2Min',imprime=True)
# Out:
# s8lp                           758ppm
# Variable
# TR+       0 days 00:02:49.811000
# M                     782.655738
# D_r                   758.816667
# Error                  23.839071
# sen0220                           758ppm
# Variable
# TR+       0 days 00:12:15.023000
# M                     757.666667
# D_r                   758.816667
# Error                      -1.15
# scd30                           758ppm
# Variable
# TR+       0 days 00:14:24.528000
# M                     715.787879
# D_r                   758.816667
# Error                 -43.028788
# cjmcu811                           758ppm
# Variable
# TR+       0 days 00:14:13.905000
# M                         4821.0
# D_r                   758.816667
# Error                4062.183333

# %%
scd30    = analiza_sensor(tb,fluke,sensor="scd30",   grafica=False,int_promedio=int2,intervalo=inte)
sen0220  = analiza_sensor(tb,fluke,sensor="sen0220", grafica=False,int_promedio=int2,intervalo=inte)
s8lp     = analiza_sensor(tb,fluke,sensor="s8lp",    grafica=False,int_promedio=int2,intervalo=inte)
cjmcu811 = analiza_sensor(tb,fluke,sensor="cjmcu811",grafica=False,int_promedio=int2,intervalo=inte)
resultados  = pd.concat([scd30,sen0220,s8lp,cjmcu811],
                             axis=1,
                              keys=['scd30','sen0220','s8lp','cjmcu811'])
resultados
# Out:
#                            scd30                 sen0220  \
#                           755ppm                  755ppm
# Variable
# TR+       0 days 00:14:24.528000  0 days 00:12:15.023000
# M                     713.536232              756.892857
# D_r                   755.388333              755.388333
# Error                 -41.852101                1.504524
#
#                             s8lp                cjmcu811
#                           755ppm                  755ppm
# Variable
# TR+       0 days 00:02:49.811000  0 days 00:14:13.905000
# M                     780.429752                 4876.59
# D_r                   755.388333              755.388333
# Error                  25.041419             4121.201667
