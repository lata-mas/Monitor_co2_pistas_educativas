# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse

# %%
from sensores import *

# %%
archivo = "../data/fluke_20-07-2021_prueba.csv"
fluke = fluke = importa_fluke(archivo)
fluke.head(3)
# Out:
#                      fluke
# tiempo
# 2021-07-20 14:30:04  469.0
# 2021-07-20 14:30:34  469.0
# 2021-07-20 14:31:04  486.0

# %%
tb = pd.read_csv("../data/sensores_20-07-2021.csv",index_col=0,parse_dates=True)
# del tb["t3022"]
sensores = tb.columns

# %%
inte = "2Min"
int2 = "10Min"
analiza_sensor(fluke,fluke,sensor="fluke",grafica=True,int_promedio=int2,intervalo=inte,imprime=True)
# Out:
# fluke                    888ppm
# Variable
# TR+       0 days 00:00:30
# M                  888.65
# D_r                888.65
# Error                 0.0
#                    888ppm
# Variable
# TR+       0 days 00:00:30
# M                  888.65
# D_r                888.65
# Error                 0.0

# %%
for sensor in sensores:
    analiza_sensor(tb,fluke,sensor=sensor,grafica=True,intervalo='2Min',imprime=True)
# Out:
# s8lp                           893ppm
# Variable
# TR+       0 days 00:32:57.611000
# M                     904.666667
# D_r                        893.9
# Error                  10.766667
# sen0220                           893ppm
# Variable
# TR+       0 days 00:25:01.633000
# M                          834.0
# D_r                        893.9
# Error                      -59.9
# t3022                           893ppm
# Variable
# TR+       0 days 00:26:00.153000
# M                          949.5
# D_r                        893.9
# Error                       55.6
# scd30                           893ppm
# Variable
# TR+       0 days 00:09:27.765000
# M                          858.0
# D_r                        893.9
# Error                      -35.9

# %%
scd30    = analiza_sensor(tb,fluke,sensor="scd30",   grafica=False,int_promedio=int2,intervalo=inte)
sen0220  = analiza_sensor(tb,fluke,sensor="sen0220", grafica=False,int_promedio=int2,intervalo=inte)
s8lp     = analiza_sensor(tb,fluke,sensor="s8lp",    grafica=False,int_promedio=int2,intervalo=inte)
t3022    = analiza_sensor(tb,fluke,sensor="t3022",   grafica=False,int_promedio=int2,intervalo=inte)
resultados = pd.concat([scd30,sen0220,s8lp,t3022],
                             axis=1,
                              keys=['scd30','sen0220','s8lp','cjmcu811'])
resultados.to_csv("../data/resultado_893ppm.csv")

resultados
# Out:
#                            scd30                 sen0220  \
#                           888ppm                  888ppm
# Variable
# TR+       0 days 00:09:27.765000  0 days 00:25:01.633000
# M                          852.9                   832.7
# D_r                       888.65                  888.65
# Error                     -35.75                  -55.95
#
#                             s8lp                cjmcu811
#                           888ppm                  888ppm
# Variable
# TR+       0 days 00:32:57.611000  0 days 00:26:00.153000
# M                     902.636364              948.909091
# D_r                       888.65                  888.65
# Error                  13.986364               60.259091
