# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse

# %%
from sensores import *

# %%
archivo = "../data/fluke_26-07-2021_625ppm.csv"
fluke = pd.read_csv(archivo,index_col=0,parse_dates=True)
fluke.head(3)
# Out:
#                      fluke
# tiempo
# 2021-07-26 14:51:00  381.0
# 2021-07-26 14:51:01  381.0
# 2021-07-26 14:51:02  380.0

# %%
tb = pd.read_csv("../data/sensores_26-07-2021_625ppm.csv",index_col=0,parse_dates=True)
del tb["t3022"]
sensores = tb.columns

# %%
inte = "1Min"
int2 = "10Min"
analiza_sensor(fluke,fluke,sensor="fluke",grafica=True,int_promedio=int2,intervalo=inte,imprime=True)
# Out:
# fluke                            TR+  Error
# sensor concentracion
# fluke  633ppm         0.016667    0.0
#                       Error       TR+           M         D_r
# sensor concentracion
# fluke  633ppm           0.0  0.016667  633.043333  633.043333

# %%
for sensor in sensores:
    analiza_sensor(tb,fluke,sensor=sensor,grafica=True,intervalo='2Min',imprime=True)
# Out:
# s8lp                            TR+      Error
# sensor concentracion
# s8lp   629ppm         0.083283  29.189399
# sen0220                             TR+      Error
# sensor  concentracion
# sen0220 629ppm         3.941033  16.210476
# scd30                            TR+     Error
# sensor concentracion
# scd30  629ppm         3.550133  43.88991
# cjmcu811                               TR+        Error
# sensor   concentracion
# cjmcu811 629ppm         13.631883  3596.273333

# %%
scd30    = analiza_sensor(tb,fluke,sensor="scd30",   grafica=False,int_promedio=int2,intervalo=inte)
sen0220  = analiza_sensor(tb,fluke,sensor="sen0220", grafica=False,int_promedio=int2,intervalo=inte)
s8lp     = analiza_sensor(tb[35:],fluke,sensor="s8lp",grafica=True,int_promedio=int2,intervalo=inte)
cjmcu811 = analiza_sensor(tb,fluke,sensor="cjmcu811",grafica=False,int_promedio=int2,intervalo=inte)
resultados = pd.concat([scd30,sen0220,s8lp,cjmcu811],
                             axis=0)

resultados.to_csv("../data/resultado_625ppm.csv")
resultados
# Out:
#                               Error        TR+            M         D_r
# sensor   concentracion
# scd30    633ppm           46.962252   2.730817   586.081081  633.043333
# sen0220  633ppm           12.004286   3.393717   645.047619  633.043333
# s8lp     633ppm           26.105427   1.915433   659.148760  633.043333
# cjmcu811 633ppm         3629.196667  10.523850  4262.240000  633.043333
