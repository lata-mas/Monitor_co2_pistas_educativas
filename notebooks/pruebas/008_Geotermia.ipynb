# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
archivo = '../../data/geotermia_400ppm.csv'
geo = pd.read_csv(archivo,skiprows=1,index_col=1)

# %%
geo.CO2.plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='sec'>

# %%
file = '../../data/sensores_prueba_08-09-2021.csv'
monitor = pd.read_csv(file,index_col=0,parse_dates=True)
monitor.s8lp
# Out:
# ts
# 2021-09-08 00:00:36.467      NaN
# 2021-09-08 00:00:39.161    501.0
# 2021-09-08 00:00:40.203      NaN
# 2021-09-08 00:01:37.627      NaN
# 2021-09-08 00:01:39.155    501.0
#                            ...
# 2021-09-08 23:58:40.353    513.0
# 2021-09-08 23:58:50.287      NaN
# 2021-09-08 23:59:17.637      NaN
# 2021-09-08 23:59:40.352    514.0
# 2021-09-08 23:59:50.285      NaN
# Name: s8lp, Length: 4298, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.scatter(monitor.index,   monitor.s8lp-430)
ax.scatter(monitor.index,monitor.sen0220-430)
ax.scatter(monitor.index,  monitor.scd30-430,label='scd30')
ax.set_ylim(-50,100)
ax.legend()
