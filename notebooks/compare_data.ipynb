# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
aranet = pd.read_csv("../data/aranet4.csv",index_col=0,parse_dates=True,
                    names=["aranet","To","HR","P"],skiprows=1)

# %%
sen = pd.read_csv("../data/sen.csv",index_col=0,parse_dates=True,
                    names=["sen"],skiprows=1)

# %%
fig, ax = plt.subplots(figsize=(10,6))

# fecha1 = parse("2021-06-09") 
# fecha2 = fecha1 + pd.Timedelta("1D")

# ax.set_xlim(fecha1,fecha2)
ax.set_ylim(300,1000)
ax.set_ylabel("CO2 [ppm]")
ax.set_xlabel("tiempo")
# ax.set_title("Mediciones CO2")

ax.plot(aranet.aranet,"g-+",alpha=0.4)
ax.plot(sen.sen,"r.",alpha=0.4)
