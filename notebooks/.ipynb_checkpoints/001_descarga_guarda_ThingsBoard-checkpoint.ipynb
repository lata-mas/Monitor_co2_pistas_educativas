# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dateutil.parser import parse
from tb import *

# %%
tb = TB(config_file='config_gbv.ini',device_name='CO2')
# Out:
# ["cdm4160","cjmcu811","fatal","heartbeat","loadavg1","loadavg15","loadavg5","mh-z14a","notice","sen0219","sen0219avg","sen0219cma","sen0220","t3022","uptime","uptime-linux"]

# %%
sensores = ["cdm4160","cjmcu811","sen0219","t3022","mh-z14a","sen0220"]
datos = pd.concat([tb.get_df(key=sensor) for sensor in sensores],axis=1)
# print(datos.head())
datos.index = datos.index + pd.Timedelta("-6H")
# print(datos.head())

# %%
#corta los datos de la fecha inicial al final
datos = datos["2021-06-24":]
datos
# Out:
#                          cdm4160  cjmcu811  sen0219   t3022  mh-z14a  sen0220
# ts
# 2021-06-24 00:00:13.202      NaN       NaN   1809.0  1501.0   1427.0      NaN
# 2021-06-24 00:00:29.951      NaN       NaN   1456.0  1503.0   1426.0      NaN
# 2021-06-24 00:00:46.695      NaN       NaN   1728.0  1504.0   1427.0      NaN
# 2021-06-24 00:01:03.430      NaN       NaN   1818.0  1506.0   1426.0      NaN
# 2021-06-24 00:01:20.201      NaN       NaN   1468.0  1506.0   1427.0      NaN
# ...                          ...       ...      ...     ...      ...      ...
# 2021-06-25 04:50:20.328     98.0       NaN      NaN     NaN      NaN      NaN
# 2021-06-25 04:50:20.843      NaN       NaN      NaN     NaN      NaN    358.0
# 2021-06-25 04:50:25.239      NaN    2412.0      NaN     NaN      NaN      NaN
# 2021-06-25 04:50:26.882     85.0       NaN      NaN     NaN      NaN      NaN
# 2021-06-25 04:50:27.397      NaN       NaN      NaN     NaN      NaN    357.0
#
# [33629 rows x 6 columns]

# %%
sensores = ["cdm4160","cjmcu811","sen0219","t3022","mh-z14a","sen0220"]

fig, ax = plt.subplots(figsize=(10,3))

# fecha1 = parse("2021-06-22") 
# fecha2 = fecha1 + pd.Timedelta("1D")
# ax.set_xlim(fecha1,fecha2)

ax.set_ylim(300,2500)
ax.set_ylabel("CO2 [ppm]")
ax.set_xlabel("tiempo")
ax.set_title("Sensores")
ax.grid()

for sensor in sensores:
    ax.scatter(datos[sensor].index,datos[sensor],label=sensor,alpha=0.2)

ax.legend()

# %%
#ajustar fecha si es necesario
datos.to_csv("../data/sensores_20210624_20210625.csv")
